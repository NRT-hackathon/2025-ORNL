# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ensemble = pd.read_csv('results/ensemble/ensemble_weighting_schemes.csv')

# %%
ensemble.sort_values(by='miou', ascending=False)
# Out:
#                 weighting_scheme  sequence_length      miou  precision  \
# 181  cnn3d_1.0_vit_0.0_mamba_0.2                5  0.804790   0.726854
# 145  cnn3d_0.8_vit_0.0_mamba_0.2                5  0.804707   0.724970
# 109  cnn3d_0.6_vit_0.0_mamba_0.2                5  0.804427   0.722402
# 182  cnn3d_1.0_vit_0.0_mamba_0.4                5  0.803630   0.719149
# 180  cnn3d_1.0_vit_0.0_mamba_0.0                5  0.802667   0.729071
# ..                           ...              ...       ...        ...
# 3    cnn3d_0.0_vit_0.0_mamba_0.6                5  0.505866   0.102171
# 5    cnn3d_0.0_vit_0.0_mamba_1.0                5  0.505866   0.102171
# 221                   mamba_only                5  0.505866   0.102171
# 2    cnn3d_0.0_vit_0.0_mamba_0.4                5  0.505866   0.102171
# 1    cnn3d_0.0_vit_0.0_mamba_0.2                5  0.505866   0.102171
#
#        recall        f1  accuracy   pos_iou
# 181  0.802875  0.762975  0.992880  0.616783
# ...

# %%
ensemble.sort_values(by='f1', ascending=False)
# Out:
#                 weighting_scheme  sequence_length      miou  precision  \
# 181  cnn3d_1.0_vit_0.0_mamba_0.2                5  0.804790   0.726854
# 145  cnn3d_0.8_vit_0.0_mamba_0.2                5  0.804707   0.724970
# 109  cnn3d_0.6_vit_0.0_mamba_0.2                5  0.804427   0.722402
# 182  cnn3d_1.0_vit_0.0_mamba_0.4                5  0.803630   0.719149
# 180  cnn3d_1.0_vit_0.0_mamba_0.0                5  0.802667   0.729071
# ..                           ...              ...       ...        ...
# 18   cnn3d_0.0_vit_0.6_mamba_0.0                5  0.515999   0.103525
# 220                     vit_only                5  0.515999   0.103525
# 24   cnn3d_0.0_vit_0.8_mamba_0.0                5  0.515999   0.103525
# 12   cnn3d_0.0_vit_0.4_mamba_0.0                5  0.515999   0.103525
# 30   cnn3d_0.0_vit_1.0_mamba_0.0                5  0.515999   0.103525
#
#        recall        f1  accuracy   pos_iou
# 181  0.802875  0.762975  0.992880  0.616783
# ...

# %%
ensemble.sort_values(by='precision', ascending=False)
# Out:
#                 weighting_scheme  sequence_length      miou  precision  \
# 186  cnn3d_1.0_vit_0.2_mamba_0.0                5  0.798119   0.789035
# 187  cnn3d_1.0_vit_0.2_mamba_0.2                5  0.798282   0.785976
# 216                  cnn3d_focus                5  0.798282   0.785976
# 151  cnn3d_0.8_vit_0.2_mamba_0.2                5  0.789174   0.784486
# 150  cnn3d_0.8_vit_0.2_mamba_0.0                5  0.787189   0.781849
# ..                           ...              ...       ...        ...
# 2    cnn3d_0.0_vit_0.0_mamba_0.4                5  0.505866   0.102171
# 5    cnn3d_0.0_vit_0.0_mamba_1.0                5  0.505866   0.102171
# 4    cnn3d_0.0_vit_0.0_mamba_0.8                5  0.505866   0.102171
# 221                   mamba_only                5  0.505866   0.102171
# 1    cnn3d_0.0_vit_0.0_mamba_0.2                5  0.505866   0.102171
#
#        recall        f1  accuracy   pos_iou
# 186  0.718994  0.752388  0.993245  0.603062
# ...

# %%
ensemble.sort_values(by='recall', ascending=False)
# Out:
#                 weighting_scheme  sequence_length      miou  precision  \
# 146  cnn3d_0.8_vit_0.0_mamba_0.4                5  0.801632   0.712992
# 73   cnn3d_0.4_vit_0.0_mamba_0.2                5  0.801632   0.712992
# 183  cnn3d_1.0_vit_0.0_mamba_0.6                5  0.798738   0.705616
# 182  cnn3d_1.0_vit_0.0_mamba_0.4                5  0.803630   0.719149
# 110  cnn3d_0.6_vit_0.0_mamba_0.4                5  0.795544   0.698316
# ..                           ...              ...       ...        ...
# 12   cnn3d_0.0_vit_0.4_mamba_0.0                5  0.515999   0.103525
# 24   cnn3d_0.0_vit_0.8_mamba_0.0                5  0.515999   0.103525
# 30   cnn3d_0.0_vit_1.0_mamba_0.0                5  0.515999   0.103525
# 18   cnn3d_0.0_vit_0.6_mamba_0.0                5  0.515999   0.103525
# 6    cnn3d_0.0_vit_0.2_mamba_0.0                5  0.515999   0.103525
#
#        recall        f1  accuracy   pos_iou
# 146  0.809798  0.758318  0.992632  0.610719
# ...

# %%
ensemble.sort_values(by='pos_iou', ascending=False)
# Out:
#                 weighting_scheme  sequence_length      miou  precision  \
# 181  cnn3d_1.0_vit_0.0_mamba_0.2                5  0.804790   0.726854
# 145  cnn3d_0.8_vit_0.0_mamba_0.2                5  0.804707   0.724970
# 109  cnn3d_0.6_vit_0.0_mamba_0.2                5  0.804427   0.722402
# 182  cnn3d_1.0_vit_0.0_mamba_0.4                5  0.803630   0.719149
# 180  cnn3d_1.0_vit_0.0_mamba_0.0                5  0.802667   0.729071
# ..                           ...              ...       ...        ...
# 18   cnn3d_0.0_vit_0.6_mamba_0.0                5  0.515999   0.103525
# 220                     vit_only                5  0.515999   0.103525
# 24   cnn3d_0.0_vit_0.8_mamba_0.0                5  0.515999   0.103525
# 12   cnn3d_0.0_vit_0.4_mamba_0.0                5  0.515999   0.103525
# 30   cnn3d_0.0_vit_1.0_mamba_0.0                5  0.515999   0.103525
#
#        recall        f1  accuracy   pos_iou
# 181  0.802875  0.762975  0.992880  0.616783
# ...
